# %%
import scanpy as sc
import numpy as np
import pandas as pd
import anndata
import os

# %%
wd = "/dss/dssfs02/lwp-dss-0001/pn36po/pn36po-dss-0001/di93vel/atlas_building/data"

# %% [markdown]
# ### Inspect unfiltered data

# %%
ref = sc.read(os.path.join(wd, "reference/Assembled10Domains.h5ad"))  # unfiltered
ref
# Out:
# AnnData object with n_obs × n_vars = 88616 × 26568
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender'
#     var: 'gene_ids', 'n_cells', 'highly_variable5891STDY8062349', 'highly_variable5891STDY8062350', 'highly_variable5891STDY8062351', 'highly_variable5891STDY8062352', 'highly_variable5891STDY8062353', 'highly_variable5891STDY8062354', 'highly_variable5891STDY8062355', 'highly_variable5891STDY8062356', 'highly_variableWSSS8012016', 'highly_variableWSSS8011222', 'highly_variableWSSS_F_LNG8713176', 'highly_variableWSSS_F_LNG8713177', 'highly_variableWSSS_F_LNG8713178', 'highly_variableWSSS_F_LNG8713179', 'highly_variableWSSS_F_LNG8713180', 'highly_variableWSSS_F_LNG8713181', 'highly_variableWSSS_F_LNG8713184', 'highly_variableWSSS_F_LNG8713185', 'highly_variableWSSS_F_LNG8713186', 'highly_variableWSSS_F_LNG8713187', 'highly_variableWSSS_F_LNG8713188', 'highly_variableWSSS_F_LNG8713189', 'highly_variableWSSS_F_LNG8713190', 'highly_variableWSSS_F_LNG8713191', 'highly_variable5891STDY9030806', 'highly_variable5891STDY9030807', 'highly_variable5891STDY9030808', 'highly_variable5891STDY9030809', 'highly_variable5891STDY9030810', 'highly_variable_n', 'highly_variable', 'Deep_5891STDY8062349', 'Deep_5891STDY8062350', 'Deep_5891STDY8062351', 'Deep_5891STDY8062352', 'Deep_5891STDY8062353', 'Deep_5891STDY8062354', 'Deep_5891STDY8062355', 'Deep_5891STDY8062356', 'Deep_WSSS8012016', 'Deep_WSSS8011222', 'Deep_WSSS_F_LNG8713176', 'Deep_WSSS_F_LNG8713177', 'Deep_WSSS_F_LNG8713178', 'Deep_WSSS_F_LNG8713179', 'Deep_WSSS_F_LNG8713180', 'Deep_WSSS_F_LNG8713181', 'Deep_WSSS_F_LNG8713184', 'Deep_WSSS_F_LNG8713185', 'Deep_WSSS_F_LNG8713186', 'Deep_WSSS_F_LNG8713187', 'Deep_WSSS_F_LNG8713188', 'Deep_WSSS_F_LNG8713189', 'Deep_WSSS_F_LNG8713190', 'Deep_WSSS_F_LNG8713191', 'Deep_5891STDY9030806', 'Deep_5891STDY9030807', 'Deep_5891STDY9030808', 'Deep_5891STDY9030809', 'Deep_5891STDY9030810', 'Deep_n', 'gene_ids-C0', 'n_cells-C0', 'highly_variable5891STDY8062349-C0', 'highly_variable5891STDY8062350-C0', 'highly_variable5891STDY8062351-C0', 'highly_variable5891STDY8062352-C0', 'highly_variable5891STDY8062353-C0', 'highly_variable5891STDY8062354-C0', 'highly_variable5891STDY8062355-C0', 'highly_variable5891STDY8062356-C0', 'highly_variableWSSS8012016-C0', 'highly_variableWSSS8011222-C0', 'highly_variableWSSS_F_LNG8713176-C0', 'highly_variableWSSS_F_LNG8713177-C0', 'highly_variableWSSS_F_LNG8713178-C0', 'highly_variableWSSS_F_LNG8713179-C0', 'highly_variableWSSS_F_LNG8713180-C0', 'highly_variableWSSS_F_LNG8713181-C0', 'highly_variableWSSS_F_LNG8713184-C0', 'highly_variableWSSS_F_LNG8713185-C0', 'highly_variableWSSS_F_LNG8713186-C0', 'highly_variableWSSS_F_LNG8713187-C0', 'highly_variableWSSS_F_LNG8713188-C0', 'highly_variableWSSS_F_LNG8713189-C0', 'highly_variableWSSS_F_LNG8713190-C0', 'highly_variableWSSS_F_LNG8713191-C0', 'highly_variable5891STDY9030806-C0', 'highly_variable5891STDY9030807-C0', 'highly_variable5891STDY9030808-C0', 'highly_variable5891STDY9030809-C0', 'highly_variable5891STDY9030810-C0', 'highly_variable_n-C0', 'highly_variable-C0', 'Deep_5891STDY8062349-C0', 'Deep_5891STDY8062350-C0', 'Deep_5891STDY8062351-C0', 'Deep_5891STDY8062352-C0', 'Deep_5891STDY8062353-C0', 'Deep_5891STDY8062354-C0', 'Deep_5891STDY8062355-C0', 'Deep_5891STDY8062356-C0', 'Deep_WSSS8012016-C0', 'Deep_WSSS8011222-C0', 'Deep_WSSS_F_LNG8713176-C0', 'Deep_WSSS_F_LNG8713177-C0', 'Deep_WSSS_F_LNG8713178-C0', 'Deep_WSSS_F_LNG8713179-C0', 'Deep_WSSS_F_LNG8713180-C0', 'Deep_WSSS_F_LNG8713181-C0', 'Deep_WSSS_F_LNG8713184-C0', 'Deep_WSSS_F_LNG8713185-C0', 'Deep_WSSS_F_LNG8713186-C0', 'Deep_WSSS_F_LNG8713187-C0', 'Deep_WSSS_F_LNG8713188-C0', 'Deep_WSSS_F_LNG8713189-C0', 'Deep_WSSS_F_LNG8713190-C0', 'Deep_WSSS_F_LNG8713191-C0', 'Deep_5891STDY9030806-C0', 'Deep_5891STDY9030807-C0', 'Deep_5891STDY9030808-C0', 'Deep_5891STDY9030809-C0', 'Deep_5891STDY9030810-C0', 'Deep_n-C0', 'means-C0', 'dispersions-C0', 'dispersions_norm-C0', 'gene_ids-C1', 'n_cells-C1', 'highly_variable5891STDY8062349-C1', 'highly_variable5891STDY8062350-C1', 'highly_variable5891STDY8062351-C1', 'highly_variable589 ...
#     uns: 'batch_colors', 'big_cluster_colors', 'new_celltype_colors', 'rank_genes_groups_global'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
# it looks like the data has been normalized and log transformed
print(np.max(ref.X))
print(np.min(ref.X))
# Out:
# 8.737457
# 0.0

# %%
ref.obs
# Out:
#                                             batch  stage  dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349  5891STDY8062349   18.0    Proximal
# AAACCTGCAATCAGAA-5891STDY8062349  5891STDY8062349   18.0    Proximal
# AAACCTGCACCGAATT-5891STDY8062349  5891STDY8062349   18.0    Proximal
# AAACCTGGTGTCAATC-5891STDY8062349  5891STDY8062349   18.0    Proximal
# AAACCTGTCAATCACG-5891STDY8062349  5891STDY8062349   18.0    Proximal
# AAACCTGCAATCAGAA-5891STDY8062349            κ small pre-B          C5
# AAACCTGCACCGAATT-5891STDY8062349           Alveolar fibro          C0
# AAACCTGGTGTCAATC-5891STDY8062349                 LowQ SMC          C0
# AAACCTGTCAATCACG-5891STDY8062349                 SPP1+ MΦ          C2
# ...                                                   ...         ...
# TTTGTCAGTTATCACG-5891STDY9030810           Vascular SMC 2          C0
# TTTGTCAGTTGGTTTG-5891STDY9030810                Mid fibro          C0
# TTTGTCATCGGATGTT-5891STDY9030810                Mid fibro          C0
# TTTGTCATCTTACCTA-5891STDY9030810                Mid fibro          C0
# TTTGTCATCTTCATGT-5891STDY9030810  Definitive reticulocyte          C3
#
#                                             donor           gender
# AAACCTGAGACAGGCT-5891STDY8062349        HDBR14808                M
# AAACCTGCAATCAGAA-5891STDY8062349        HDBR14808                M
# AAACCTGCACCGAATT-5891STDY8062349        HDBR14808                M
# AAACCTGGTGTCAATC-5891STDY8062349        HDBR14808                M
# AAACCTGTCAATCACG-5891STDY8062349        HDBR14808                M
# ...                                           ...              ...
# TTTGTCAGTTATCACG-5891STDY9030810        HDBR15280                M
# TTTGTCAGTTGGTTTG-5891STDY9030810        HDBR15280                M
# TTTGTCATCGGATGTT-5891STDY9030810        HDBR15280                M
# TTTGTCATCTTACCTA-5891STDY9030810        HDBR15280                M
# TTTGTCATCTTCATGT-5891STDY9030810  HDBR15279+15280  HDBR15279+15280
#
# [88616 rows x 17 columns]

# %%
ref.obs['big_cluster'].value_counts()
# Out:
# C0    46688
# C1    11349
# C2     8723
# C3     8692
# C4     5433
# C5     4723
# C6     2227
# C7      748
# C8       22
# C9       11
# Name: big_cluster, dtype: int64

# %%
ref.obs['dissection'].value_counts()
# Out:
# Whole-lung    30453
# Proximal      29174
# Distal        28989
# Name: dissection, dtype: int64

# %%
ref.obs['new_celltype'].value_counts()
# Out:
# Mid fibro                11234
# Alveolar fibro            8289
# Early fibro               5858
# LowQ fibro                3671
# Interm fibro              3157
#                          ...
# SMG                          7
# Proliferating Schwann        7
# AT-neuro doub                7
# Basophil                     7
# RBC-ciliated doub            4
# Name: new_celltype, Length: 222, dtype: int64

# %%
# it looks like there are still cells that express less than 200 genes and genes that are expressed in less than 5 cells in the data set
adata = ref
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=5)
adata.shape
# Out:
# (88593, 26463)

# %%
mean = np.mean(adata.X, axis=0)
print(mean.shape)
print(mean)
# Out:
# (1, 26463)
# [[7.6909311e-04 1.5505063e-04 1.2826096e-03 ... 3.6380584e-03
#   1.3095222e-01 1.2800039e-04]]

# %%
# it looks like the data was not scaled
var = np.var(adata.X.todense(), axis=0)
print(var.shape)
print(var)
# Out:
# (1, 26463)
# [[7.3349033e-04 1.7099440e-04 1.3925508e-03 ... 1.1958502e-02
#   1.2709533e-01 1.0634876e-04]]

# %% [markdown]
# ### Inspect filtered data

# %%
ref_filtered = sc.read(os.path.join(wd, "reference/Assembled10DomainsFiltered.h5ad"))  # filtered
ref_filtered
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26568
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
#     var: 'gene_ids', 'n_cells', 'highly_variable5891STDY8062349', 'highly_variable5891STDY8062350', 'highly_variable5891STDY8062351', 'highly_variable5891STDY8062352', 'highly_variable5891STDY8062353', 'highly_variable5891STDY8062354', 'highly_variable5891STDY8062355', 'highly_variable5891STDY8062356', 'highly_variableWSSS8012016', 'highly_variableWSSS8011222', 'highly_variableWSSS_F_LNG8713176', 'highly_variableWSSS_F_LNG8713177', 'highly_variableWSSS_F_LNG8713178', 'highly_variableWSSS_F_LNG8713179', 'highly_variableWSSS_F_LNG8713180', 'highly_variableWSSS_F_LNG8713181', 'highly_variableWSSS_F_LNG8713184', 'highly_variableWSSS_F_LNG8713185', 'highly_variableWSSS_F_LNG8713186', 'highly_variableWSSS_F_LNG8713187', 'highly_variableWSSS_F_LNG8713188', 'highly_variableWSSS_F_LNG8713189', 'highly_variableWSSS_F_LNG8713190', 'highly_variableWSSS_F_LNG8713191', 'highly_variable5891STDY9030806', 'highly_variable5891STDY9030807', 'highly_variable5891STDY9030808', 'highly_variable5891STDY9030809', 'highly_variable5891STDY9030810', 'highly_variable_n', 'highly_variable', 'Deep_5891STDY8062349', 'Deep_5891STDY8062350', 'Deep_5891STDY8062351', 'Deep_5891STDY8062352', 'Deep_5891STDY8062353', 'Deep_5891STDY8062354', 'Deep_5891STDY8062355', 'Deep_5891STDY8062356', 'Deep_WSSS8012016', 'Deep_WSSS8011222', 'Deep_WSSS_F_LNG8713176', 'Deep_WSSS_F_LNG8713177', 'Deep_WSSS_F_LNG8713178', 'Deep_WSSS_F_LNG8713179', 'Deep_WSSS_F_LNG8713180', 'Deep_WSSS_F_LNG8713181', 'Deep_WSSS_F_LNG8713184', 'Deep_WSSS_F_LNG8713185', 'Deep_WSSS_F_LNG8713186', 'Deep_WSSS_F_LNG8713187', 'Deep_WSSS_F_LNG8713188', 'Deep_WSSS_F_LNG8713189', 'Deep_WSSS_F_LNG8713190', 'Deep_WSSS_F_LNG8713191', 'Deep_5891STDY9030806', 'Deep_5891STDY9030807', 'Deep_5891STDY9030808', 'Deep_5891STDY9030809', 'Deep_5891STDY9030810', 'Deep_n', 'gene_ids-C0', 'n_cells-C0', 'highly_variable5891STDY8062349-C0', 'highly_variable5891STDY8062350-C0', 'highly_variable5891STDY8062351-C0', 'highly_variable5891STDY8062352-C0', 'highly_variable5891STDY8062353-C0', 'highly_variable5891STDY8062354-C0', 'highly_variable5891STDY8062355-C0', 'highly_variable5891STDY8062356-C0', 'highly_variableWSSS8012016-C0', 'highly_variableWSSS8011222-C0', 'highly_variableWSSS_F_LNG8713176-C0', 'highly_variableWSSS_F_LNG8713177-C0', 'highly_variableWSSS_F_LNG8713178-C0', 'highly_variableWSSS_F_LNG8713179-C0', 'highly_variableWSSS_F_LNG8713180-C0', 'highly_variableWSSS_F_LNG8713181-C0', 'highly_variableWSSS_F_LNG8713184-C0', 'highly_variableWSSS_F_LNG8713185-C0', 'highly_variableWSSS_F_LNG8713186-C0', 'highly_variableWSSS_F_LNG8713187-C0', 'highly_variableWSSS_F_LNG8713188-C0', 'highly_variableWSSS_F_LNG8713189-C0', 'highly_variableWSSS_F_LNG8713190-C0', 'highly_variableWSSS_F_LNG8713191-C0', 'highly_variable5891STDY9030806-C0', 'highly_variable5891STDY9030807-C0', 'highly_variable5891STDY9030808-C0', 'highly_variable5891STDY9030809-C0', 'highly_variable5891STDY9030810-C0', 'highly_variable_n-C0', 'highly_variable-C0', 'Deep_5891STDY8062349-C0', 'Deep_5891STDY8062350-C0', 'Deep_5891STDY8062351-C0', 'Deep_5891STDY8062352-C0', 'Deep_5891STDY8062353-C0', 'Deep_5891STDY8062354-C0', 'Deep_5891STDY8062355-C0', 'Deep_5891STDY8062356-C0', 'Deep_WSSS8012016-C0', 'Deep_WSSS8011222-C0', 'Deep_WSSS_F_LNG8713176-C0', 'Deep_WSSS_F_LNG8713177-C0', 'Deep_WSSS_F_LNG8713178-C0', 'Deep_WSSS_F_LNG8713179-C0', 'Deep_WSSS_F_LNG8713180-C0', 'Deep_WSSS_F_LNG8713181-C0', 'Deep_WSSS_F_LNG8713184-C0', 'Deep_WSSS_F_LNG8713185-C0', 'Deep_WSSS_F_LNG8713186-C0', 'Deep_WSSS_F_LNG8713187-C0', 'Deep_WSSS_F_LNG8713188-C0', 'Deep_WSSS_F_LNG8713189-C0', 'Deep_WSSS_F_LNG8713190-C0', 'Deep_WSSS_F_LNG8713191-C0', 'Deep_5891STDY9030806-C0', 'Deep_5891STDY9030807-C0', 'Deep_5891STDY9030808-C0', 'Deep_5891STDY9030809-C0', 'Deep_5891STDY9030810-C0', 'Deep_n-C0', 'means-C0', 'dispersions-C0', 'dispersions_norm-C0', 'gene_ids-C1', 'n_cells-C1', 'highly_variable5891STDY8062349-C1', 'highly_variable5891STDY8062350-C1', 'highly_variable5891STDY8062351-C1', 'highly_variable589 ...
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'dissection_colors', 'new_celltype_colors', 'phase_colors', 'rank_genes_groups_global'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
print(np.max(ref_filtered.X))
print(np.min(ref_filtered.X))
# Out:
# 8.558985
# 0.0

# %%
ref_filtered.obs
# Out:
#                                                 batch  stage dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAACCTGCACCGAATT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGATGTCGTGACAT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACAAACGTGG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACATACTACG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# ...                                               ...    ...        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  WSSS_F_LNG8713184   15.0   Proximal
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CATCGAACATTAACCG-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# TACGGGCTCACCTTAT-WSSS_F_LNG8713
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188                nan             nan
#
#                                    receptor_type receptor_subtype  \
# AAACCTGAGACAGGCT-5891STDY8062349             nan              nan
# AAACCTGCACCGAATT-5891STDY8062349             nan              nan
# AAAGATGTCGTGACAT-5891STDY8062349             nan              nan
# AAAGCAACAAACGTGG-5891STDY8062349             nan              nan
# AAAGCAACATACTACG-5891STDY8062349             nan              nan
# ...                                          ...              ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184           nan              nan
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185           nan              nan
# CATCGAACATTAACCG-WSSS_F_LNG8713185           nan              nan
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185           nan              nan
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188           nan              nan
#
#                                    broad_celltype
# AAACCTGAGACAGGCT-5891STDY8062349       Fibroblast
# AAACCTGCACCGAATT-5891STDY8062349       Fibroblast
# AAAGATGTCGTGACAT-5891STDY8062349       Fibroblast
# AAAGCAACAAACGTGG-5891STDY8062349       Fibroblast
# AAAGCAACATACTACG-5891STDY8062349       Fibroblast
# ...                                           ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  Other myeloid
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  Other myeloid
# CATCGAACATTAACCG-WSSS_F_LNG8713185  Other myeloid
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  Other myeloid
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  Other myeloid
#
# [71752 rows x 24 columns]

# %%
ref_filtered.obs['dissection'].value_counts()
# Out:
# Whole-lung    26804
# Proximal      22901
# Distal        22047
# Name: dissection, dtype: int64

# %%
ref_filtered.obs['new_celltype'].value_counts()
# Out:
# Mid fibro                11074
# Alveolar fibro            8289
# Early fibro               5858
# Interm fibro              3156
# Adventitial fibro         2403
#                          ...
# Proximal secretory 3         8
# Proliferating Schwann        7
# SMG                          7
# CMP                          7
# Basophil                     7
# Name: new_celltype, Length: 144, dtype: int64

# %%
ref_filtered.obs['broad_celltype'].value_counts()
# Out:
# Fibroblast             31413
# Myofibro & SMC          7108
# Other myeloid           6883
# Distal epithelial       6582
# Proximal epithelial     4155
# B                       4138
# Vas endothelial         2793
# NK                      2623
# T & ILC                 2155
# Meg-ery                 1707
# Lymph endothelial       1039
# PNS                      649
# Mesothelial              404
# Chondrocyte              103
# Name: broad_celltype, dtype: int64

# %%
epithelial = ref_filtered[ref_filtered.obs['broad_celltype'].isin(['Distal epithelial', 'Proximal epithelial'])]

# %%
epithelial.obs['new_celltype'].value_counts()
# Out:
# Late tip                          2127
# Mid tip                           1393
# Mid stalk                         1380
# Ciliated                          1339
# Mid airway progenitor              798
# Late stalk                         670
# Early airway progenitor            432
# AT2                                382
# AT1                                283
# Early tip                          252
# MUC16+ ciliated                    218
# Club                               208
# Late airway progenitor             193
# Pulmonary neuroendocrine           158
# Mid basal                          143
# Early stalk                         95
# GHRL+ NE precursor                  94
# Deuterosomal                        84
# GHRL+ neuroendocrine                77
# Late basal                          63
# Pulmonary NE precursor              61
# Proximal basal                      57
# Proximal secretory 1                55
# Interm neuroendocrine               50
# Proximal secretory progenitors      39
# Proximal secretory 2                26
# MUC5AC+ ASCL1+ progenitor           19
# SMG basal                           15
# Squamous                            11
# Proximal secretory 3                 8
# SMG                                  7
# Name: new_celltype, dtype: int64

# %%
# epithelial.write(os.path.join(wd, "reference/Assembled10DomainsFilteredEpithelial.h5ad"))

# %%
cell_selection = pd.unique(epithelial.obs['new_celltype'])
cell_selection
# Out:
# ['Late tip', 'Club', 'Late airway progenitor', 'Squamous', 'AT1', ..., 'SMG basal', 'MUC5AC+ ASCL1+ progenitor', 'Ciliated', 'MUC16+ ciliated', 'Deuterosomal']
# Length: 31
# Categories (31, object): ['AT1', 'AT2', 'Ciliated', 'Club', ..., 'Pulmonary neuroendocrine', 'SMG', 'SMG basal', 'Squamous']

# %% [markdown]
# ### Pre-process unfiltered data

# %%
# we select the unfiltered reference and keep only epithelial cells
sub = ref[ref.obs['new_celltype'].isin(cell_selection)]
sub.obs['new_celltype'].value_counts()
# Out:
# Late tip                          2127
# Mid tip                           1393
# Mid stalk                         1380
# Ciliated                          1339
# Mid airway progenitor              798
# Late stalk                         670
# Early airway progenitor            432
# AT2                                382
# AT1                                283
# Early tip                          252
# MUC16+ ciliated                    218
# Club                               208
# Late airway progenitor             193
# Pulmonary neuroendocrine           158
# Mid basal                          143
# Early stalk                         95
# GHRL+ NE precursor                  94
# Deuterosomal                        84
# GHRL+ neuroendocrine                77
# Late basal                          63
# Pulmonary NE precursor              61
# Proximal basal                      57
# Proximal secretory 1                55
# Proximal secretory progenitors      39
# Proximal secretory 2                26
# MUC5AC+ ASCL1+ progenitor           19
# SMG basal                           15
# Squamous                            11
# Proximal secretory 3                 8
# SMG                                  7
# Name: new_celltype, dtype: int64

# %%
# make sure every cell has been assigned a type
assert sum(sub.obs['new_celltype'].value_counts()) == sub.shape[0]

# %%
# sub.write(os.path.join(wd, "reference/Assembled10DomainsEpithelial.h5ad"))

# %% [markdown]
# ### Simplify annotation

# %%
data_dict = {
    "Ciliated": "Ciliated",
    "MUC16+ ciliated": "Ciliated",
    "Deuterosomal": "Ciliated",
    "Late airway progenitor": "Club",
    "Mid airway progenitor": "Club",
    "Early tip": "Bud Tip Progenitor",
    "Mid tip": "Bud Tip Progenitor",
    "Late tip": "Bud Tip Progenitor",
    "Pulmonary neuroendocrine": "Neuroendocrine",
    "GHRL+ neuroendocrine": "Neuroendocrine",
    "Pulmonary NE precursor": "Neuroendocrine",
    "GHRL+ NE precursor": "Neuroendocrine",
    "Early airway progenitor": "Club",
    "Early stalk": "Stalk",
    "Mid stalk": "Stalk",
    "Late stalk": "Stalk",
    "AT1": "AT1",
    "AT2": "AT2",
    "Club": "Club",
    "Proximal secretory progenitors": "Club",
    "Proximal secretory 1": "Club",
    "Proximal secretory 2": "Club",
    "Proximal secretory 3": "Club",
    "SMG": "Club",
    "Squamous": "Squamous",
    "Proximal basal": "Basal",
    "Mid basal": "Basal",
    "Late basal": "Basal",
    "SMG basal": "Basal",
    "MUC5AC+ ASCL1+ progenitor": "NA"
}

# %%
sub.obs['simplified_celltype'] = sub.obs['new_celltype'].copy().map(data_dict)
# Out:
# /tmp/ipykernel_2766380/3396919053.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   sub.obs['simplified_celltype'] = sub.obs['new_celltype'].copy().map(data_dict)

# %%
sub.obs['simplified_celltype'].value_counts()
# Out:
# Bud Tip Progenitor    3772
# Stalk                 2145
# Club                  1766
# Ciliated              1641
# Neuroendocrine         390
# AT2                    382
# AT1                    283
# Basal                  278
# NA                      19
# Squamous                11
# Name: simplified_celltype, dtype: int64

# %%
sub = sub[sub.obs['simplified_celltype'] != 'NA']

# %%
# make sure every cell has been assigned a type
# ACGAGGAGTACCGCTG-5891STDY8062349 -0.234711  -0.164004
# ACGAGGAGTCCTGCTT-5891STDY8062349 -0.240360  -0.195414
# ...                                    ...        ...
# TTGACTTCAACGATCT-5891STDY9030810  0.128544  -0.034317
# TTTACTGTCTTACCGC-5891STDY9030810  0.073263   0.077953
# TTTGCGCCAAGACACG-5891STDY9030810 -0.122121  -0.069196
# TTTGCGCTCCGTCAAA-5891STDY9030810 -0.057342  -0.101391
# TTTGGTTGTGCCTTGG-5891STDY9030810 -0.088670  -0.059531
#
#                                              new_celltype big_cluster  \
# ACACCCTAGGTAAACT-5891STDY8062349                 Ciliated          C6
# ACAGCTAAGGGTTTCT-5891STDY8062349                 Late tip          C1
# ACCCACTGTATGAAAC-5891STDY8062349                     Club          C1
# ACGAGGAGTACCGCTG-5891STDY8062349          MUC16+ ciliated          C6
# ACGAGGAGTCCTGCTT-5891STDY8062349                 Ciliated          C6
# ...                                                   ...         ...
# TTGACTTCAACGATCT-5891STDY9030810                Mid stalk          C1
# TTTACTGTCTTACCGC-5891STDY9030810   Pulmonary NE precursor          C1
# TTTGCGCCAAGACACG-5891STDY9030810     GHRL+ neuroendocrine          C1
# TTTGCGCTCCGTCAAA-5891STDY9030810  Early airway progenitor          C1
# TTTGGTTGTGCCTTGG-5891STDY9030810  Early airway progenitor          C1
#
#                                       donor gender simplified_celltype
# ACACCCTAGGTAAACT-5891STDY8062349  HDBR14808      M            Ciliated
# ACAGCTAAGGGTTTCT-5891STDY8062349  HDBR14808      M  Bud Tip Progenitor
# ACCCACTGTATGAAAC-5891STDY8062349  HDBR14808      M                Club
# ACGAGGAGTACCGCTG-5891STDY8062349  HDBR14808      M            Ciliated
# ACGAGGAGTCCTGCTT-5891STDY8062349  HDBR14808      M            Ciliated
# ...                                     ...    ...                 ...
# TTGACTTCAACGATCT-5891STDY9030810  HDBR15279      F               Stalk
# TTTACTGTCTTACCGC-5891STDY9030810  HDBR15280      M      Neuroendocrine
# TTTGCGCCAAGACACG-5891STDY9030810  HDBR15279      F      Neuroendocrine
# TTTGCGCTCCGTCAAA-5891STDY9030810  HDBR15279      F                Club
# TTTGGTTGTGCCTTGG-5891STDY9030810  HDBR15280      M                Club
#
# [10668 rows x 18 columns]

# %%
sub.shape
# Out:
# (10668, 26463)

# %%
# sub.write(os.path.join(wd, "reference/Assembled10DomainsEpithelialSimplifiedAnnotation.h5ad"))

# %% [markdown]
# ### Inspect the overlap between the mature lung cell atlas and fetal lung cell atlas annotation

# %%
import celltypist
from celltypist import models

models.download_models(force_update = True)
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 31
# 📂 Storing models in /dss/dsshome1/06/di93vel/.celltypist/data/models
# 💾 Downloading model [1/31]: Immune_All_Low.pkl
# 💾 Downloading model [2/31]: Immune_All_High.pkl
# 💾 Downloading model [3/31]: Adult_CynomolgusMacaque_Hippocampus.pkl
# 💾 Downloading model [4/31]: Adult_Mouse_Gut.pkl
# 💾 Downloading model [5/31]: Adult_Mouse_OlfactoryBulb.pkl
# 💾 Downloading model [6/31]: Adult_Pig_Hippocampus.pkl
# 💾 Downloading model [7/31]: Adult_RhesusMacaque_Hippocampus.pkl
# 💾 Downloading model [8/31]: Autopsy_COVID19_Lung.pkl
# 💾 Downloading model [9/31]: COVID19_HumanChallenge_Blood.pkl
# 💾 Downloading model [10/31]: COVID19_Immune_Landscape.pkl
# 💾 Downloading model [11/31]: Cells_Fetal_Lung.pkl
# 💾 Downloading model [12/31]: Cells_Intestinal_Tract.pkl
# 💾 Downloading model [13/31]: Cells_Lung_Airway.pkl
# 💾 Downloading model [14/31]: Developing_Human_Brain.pkl
# 💾 Downloading model [15/31]: Developing_Human_Hippocampus.pkl
# 💾 Downloading model [16/31]: Developing_Human_Thymus.pkl
# 💾 Downloading model [17/31]: Developing_Mouse_Brain.pkl
# 💾 Downloading model [18/31]: Developing_Mouse_Hippocampus.pkl
# 💾 Downloading model [19/31]: Healthy_COVID19_PBMC.pkl
# 💾 Downloading model [20/31]: Healthy_Mouse_Liver.pkl
# 💾 Downloading model [21/31]: Human_AdultAged_Hippocampus.pkl
# 💾 Downloading model [22/31]: Human_IPF_Lung.pkl
# 💾 Downloading model [23/31]: Human_Longitudinal_Hippocampus.pkl
# 💾 Downloading model [24/31]: Human_Lung_Atlas.pkl
# 💾 Downloading model [25/31]: Human_PF_Lung.pkl
# 💾 Downloading model [26/31]: Lethal_COVID19_Lung.pkl
# 💾 Downloading model [27/31]: Mouse_Dentate_Gyrus.pkl
# 💾 Downloading model [28/31]: Mouse_Isocortex_Hippocampus.pkl
# 💾 Downloading model [29/31]: Mouse_Postnatal_DentateGyrus.pkl
# 💾 Downloading model [30/31]: Nuclei_Lung_Airway.pkl
# 💾 Downloading model [31/31]: Pan_Fetal_Human.pkl

# %%
models.models_description()
# Out:
# 👉 Detailed model information can be found at `https://www.celltypist.org/models`
#                                       model  \
# 0                        Immune_All_Low.pkl
# 1                       Immune_All_High.pkl
# 2   Adult_CynomolgusMacaque_Hippocampus.pkl
# 3                       Adult_Mouse_Gut.pkl
# 4             Adult_Mouse_OlfactoryBulb.pkl
# 5                 Adult_Pig_Hippocampus.pkl
# 6       Adult_RhesusMacaque_Hippocampus.pkl
# 7                  Autopsy_COVID19_Lung.pkl
# 8          COVID19_HumanChallenge_Blood.pkl
# 9              COVID19_Immune_Landscape.pkl
# 10                     Cells_Fetal_Lung.pkl
# 11               Cells_Intestinal_Tract.pkl
# 12                    Cells_Lung_Airway.pkl
# 13               Developing_Human_Brain.pkl
# 14         Developing_Human_Hippocampus.pkl
# 15              Developing_Human_Thymus.pkl
# 16               Developing_Mouse_Brain.pkl
# 17         Developing_Mouse_Hippocampus.pkl
# 18                 Healthy_COVID19_PBMC.pkl
# 19                  Healthy_Mouse_Liver.pkl
# 20          Human_AdultAged_Hippocampus.pkl
# 21                       Human_IPF_Lung.pkl
# 22       Human_Longitudinal_Hippocampus.pkl
# 23                     Human_Lung_Atlas.pkl
# 24                        Human_PF_Lung.pkl
# 25                  Lethal_COVID19_Lung.pkl
# 26                  Mouse_Dentate_Gyrus.pkl
# 27          Mouse_Isocortex_Hippocampus.pkl
# 28         Mouse_Postnatal_DentateGyrus.pkl
# 29                   Nuclei_Lung_Airway.pkl
# 30                      Pan_Fetal_Human.pkl
#
#                                           description
# 0   immune sub-populations combined from 20 tissue...
# 1   immune populations combined from 20 tissues of...
# 2   cell types from the hippocampus of adult cynom...
# 3   cell types in the adult mouse gut combined fro...
# 4    cell types from the olfactory bulb of adult mice
# 5           cell types from the adult pig hippocampus
# 6   cell types from the hippocampus of adult rhesu...
# 7   cell types from the lungs of 16 SARS-CoV-2 inf...
# 8   detailed blood cell states from 16 individuals...
# 9   immune subtypes from lung and blood of COVID-1...
# 10    cell types from human embryonic and fetal lungs
# 11  intestinal cells from fetal, pediatric (health...
# 12  cell populations from scRNA-seq of five locati...
# 13  cell types from the first-trimester developing...
# 14   cell types from the developing human hippocampus
# 15  cell populations in embryonic, fetal, pediatri...
# 16  cell types from the embryonic mouse brain betw...
# 17  cell types from the mouse hippocampus at postn...
# 18  peripheral blood mononuclear cell types from h...
# 19  cell types from scRNA-seq and snRNA-seq of the...
# 20  cell types from the hippocampus of adult and a...
# 21  cell types from idiopathic pulmonary fibrosis,...
# 22  cell types from the adult human anterior and p...
# 23  integrated Human Lung Cell Atlas (HLCA) combin...
# 24  cell types from different forms of pulmonary f...
# 25  cell types from the lungs of individuals who d...
# 26  cell types from the dentate gyrus in perinatal...
# 27  cell types from the adult mouse isocortex (neo...
# 28  cell types from the mouse dentate gyrus in pos...
# 29  cell populations from snRNA-seq of five locati...
# 30  stromal and immune populations from the human ...

# %%
human_lung_model = models.Model.load(model = 'Human_Lung_Atlas.pkl')

# %%
print([c for c in human_lung_model.cell_types])
# Out:
# ['AT0', 'AT1', 'AT2', 'AT2 proliferating', 'Adventitial fibroblasts', 'Alveolar Mph CCL3+', 'Alveolar Mph MT-positive', 'Alveolar Mph proliferating', 'Alveolar fibroblasts', 'Alveolar macrophages', 'B cells', 'Basal resting', 'CD4 T cells', 'CD8 T cells', 'Classical monocytes', 'Club (nasal)', 'Club (non-nasal)', 'DC1', 'DC2', 'Deuterosomal', 'EC aerocyte capillary', 'EC arterial', 'EC general capillary', 'EC venous pulmonary', 'EC venous systemic', 'Goblet (bronchial)', 'Goblet (nasal)', 'Goblet (subsegmental)', 'Hematopoietic stem cells', 'Hillock-like', 'Interstitial Mph perivascular', 'Ionocyte', 'Lymphatic EC differentiating', 'Lymphatic EC mature', 'Lymphatic EC proliferating', 'Mast cells', 'Mesothelium', 'Migratory DCs', 'Monocyte-derived Mph', 'Multiciliated (nasal)', 'Multiciliated (non-nasal)', 'Myofibroblasts', 'NK cells', 'Neuroendocrine', 'Non-classical monocytes', 'Peribronchial fibroblasts', 'Pericytes', 'Plasma cells', 'Plasmacytoid DCs', 'SM activated stress response', 'SMG duct', 'SMG mucous', 'SMG serous (bronchial)', 'SMG serous (nasal)', 'Smooth muscle', 'Smooth muscle FAM83D+', 'Subpleural fibroblasts', 'Suprabasal', 'T cells proliferating', 'Tuft', 'pre-TB secretory']

# %%
fetal_lung_model = models.Model.load(model = 'Cells_Fetal_Lung.pkl')

# %%
print([c for c in fetal_lung_model.cell_types])
# Out:
# ['ACTC+ SMC', 'APOE+ MΦ1', 'APOE+ MΦ2', 'ASPN+ chondrocyte', 'AT1', 'AT2', 'Activated NK', 'Adventitial fibro', 'Aerocyte', 'Airway fibro', 'Alveolar fibro', 'Arterial endo', 'Basophil', 'CD16+ NK', 'CD4 T', 'CD5+ CCL22+ mature B', 'CD5+ CCL22- mature B', 'CD5- Mature B', 'CD56bright NK', 'CD8 T', 'CMP', 'COL20A1+ Schwann', 'CX3CR1+ MΦ', 'CXCL9+ MΦ', 'Ciliated', 'Club', 'Cycling DC', 'Cycling NK', 'Cycling T', 'Cycling definitive erythroblast', 'DC1', 'DC2', 'DC3', 'Definitive erythroblast', 'Definitive erythrocyte', 'Definitive reticulocyte', 'Deuterosomal', 'Early Schwann', 'Early airway progenitor', 'Early cap', 'Early fibro', 'Early mesothelial', 'Early stalk', 'Early tip', 'Eosinophil', 'FGFBP2+ Neural progenitor', 'GHRL+ NE precursor', 'GHRL+ neuroendocrine', 'GMP', 'GRIA2+ arterial endo', 'HMOX1+ primitive erythroblast', 'HSC', 'HSC/ELP', 'ILC2', 'ILC3', 'ILCP', 'Immature B', 'Interm chondrocyte', 'Interm fibro', 'Interm neuroendocrine', 'Intermediate NK', 'Intermediate lymphatic endo', 'KCNIP4+ neuron', 'Large pre-B', 'Late Schwann', 'Late airway SMC', 'Late airway progenitor', 'Late basal', 'Late cap', 'Late mesothelial', 'Late pre-B', 'Late pro-B', 'Late stalk', 'Late tip', 'Lymphatic endo', 'MEP', 'MFNG+ DBH+ neuron', 'MUC16+ ciliated', 'MUC5AC+ ASCL1+ progenitor', 'MYL4+ SMC', 'Mast', 'Megakaryocyte', 'Mesenchymal 1', 'Mesenchymal 2', 'Mesenchymal 3', 'Mid Schwann', 'Mid airway SMC 1', 'Mid airway SMC 2', 'Mid airway progenitor', 'Mid basal', 'Mid cap', 'Mid fibro', 'Mid mesothelial', 'Mid stalk', 'Mid tip', 'Myelocyte-like', 'Myofibro 1', 'Myofibro 2', 'Myofibro 3', 'NKT1', 'NKT2', 'Neutrophil', 'Non-cla. mono.', 'OMD+ endo', 'PCP4+ neuron', 'Pericyte', 'Platelet', 'Primitive erythrocyte', 'Pro-B', 'Pro-B/Pre-B transition', 'Proliferating Schwann', 'Promonocyte-like', 'Promyelocyte-like', 'Proximal basal', 'Proximal secretory 1', 'Proximal secretory 2', 'Proximal secretory 3', 'Proximal secretory progenitors', 'Pulmonary NE precursor', 'Pulmonary neuroendocrine', 'Resting chondrocyte', 'S100A12-hi cla. mono.', 'S100A12-lo cla. mono.', 'SCG3+ lymphatic endothelial', 'SMG', 'SMG basal', 'SPP1+ MΦ', 'SST+ neuron', 'Schwann precursor', 'Squamous', 'TM4SF4+ CHODL+ neuron', 'TM4SF4+ PENK+ neuron', 'Th17', 'Treg', 'Tαβ_Entry', 'Vascular SMC 1', 'Vascular SMC 2', 'Venous endo', 'aDC 1', 'aDC 2', 'pDC', 'pre-pDC/DC5', 'κ small pre-B', 'λ small pre-B']

# %%
mat = set(human_lung_model.cell_types)
fet = set(fetal_lung_model.cell_types)

# %%
print(mat.intersection(fet))
# Out:
# {'Deuterosomal', 'AT2', 'AT1', 'DC2', 'DC1'}
